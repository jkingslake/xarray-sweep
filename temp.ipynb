# %%
import xarray as xr
import sys
import numpy as np
import time
import random
sys.path.insert(0, "/Users/jkingslake/Documents/science/xarray-sweep/src")
from dask.diagnostics import ProgressBar

from xarray_sweep import grid_search, gridSearch, xarray_sweep

# %%
# %%time
def fn(a: int, b: int) -> int:
    rng = np.random.default_rng(11)

    return a + np.mean(rng.normal(size=100000000))

out = xarray_sweep(fn, use_dask=True, show_progress=True, a=np.arange(100), b=np.arange(1))
out
# Out:
# CPU times: user 1.65 s, sys: 342 ms, total: 1.99 s
# Wall time: 15.1 s
# <xarray.DataArray (a: 100, b: 1)> Size: 800B
# array([[-1.59132358e-05],
#        [ 9.99984087e-01],
#        [ 1.99998409e+00],
#        [ 2.99998409e+00],
#        [ 3.99998409e+00],
#        [ 4.99998409e+00],
#        [ 5.99998409e+00],
#        [ 6.99998409e+00],
#        [ 7.99998409e+00],
#        [ 8.99998409e+00],
#        [ 9.99998409e+00],
#        [ 1.09999841e+01],
#        [ 1.19999841e+01],
#        [ 1.29999841e+01],
#        [ 1.39999841e+01],
#        [ 1.49999841e+01],
#        [ 1.59999841e+01],
#        [ 1.69999841e+01],
#        [ 1.79999841e+01],
#        [ 1.89999841e+01],
# ...
#        [ 7.99999841e+01],
#        [ 8.09999841e+01],
#        [ 8.19999841e+01],
#        [ 8.29999841e+01],
#        [ 8.39999841e+01],
#        [ 8.49999841e+01],
#        [ 8.59999841e+01],
#        [ 8.69999841e+01],
#        [ 8.79999841e+01],
#        [ 8.89999841e+01],
#        [ 8.99999841e+01],
# ...

# %%
# %%time
def fn(a: int, b: int) -> int:
    rng = np.random.default_rng(11)

    return a + np.mean(rng.normal(size=100000000))

out = xarray_sweep(fn, use_dask=True, compute=False, a=np.arange(30), b=np.arange(1))
out
# Out:
# CPU times: user 4.78 ms, sys: 1.02 ms, total: 5.8 ms
# Wall time: 5.41 ms
# Delayed('_assemble_outputs-31101873-c5b6-4269-a9e2-28bcb7bb012a')

# %%
with ProgressBar():
    out.compute()
# Out:
# [########################################] | 100% Completed | 4.78 ss

# %%
# %%time
def fn(a: int, b: int) -> int:
    rng = np.random.default_rng(11)

    return a + np.mean(rng.normal(size=100000000))

out = xarray_sweep(fn, use_dask=False, show_progress=True, a=np.arange(100), b=np.arange(1))
out
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 53 s, sys: 5.7 s, total: 58.7 s
# Wall time: 57.2 s
# <xarray.DataArray (a: 100, b: 1)> Size: 800B
# array([[-1.59132358e-05],
#        [ 9.99984087e-01],
#        [ 1.99998409e+00],
#        [ 2.99998409e+00],
#        [ 3.99998409e+00],
#        [ 4.99998409e+00],
#        [ 5.99998409e+00],
#        [ 6.99998409e+00],
#        [ 7.99998409e+00],
#        [ 8.99998409e+00],
#        [ 9.99998409e+00],
#        [ 1.09999841e+01],
#        [ 1.19999841e+01],
#        [ 1.29999841e+01],
#        [ 1.39999841e+01],
#        [ 1.49999841e+01],
#        [ 1.59999841e+01],
#        [ 1.69999841e+01],
#        [ 1.79999841e+01],
#        [ 1.89999841e+01],
# ...
#        [ 7.99999841e+01],
#        [ 8.09999841e+01],
#        [ 8.19999841e+01],
#        [ 8.29999841e+01],
#        [ 8.39999841e+01],
#        [ 8.49999841e+01],
#        [ 8.59999841e+01],
#        [ 8.69999841e+01],
#        [ 8.79999841e+01],
# ...

# %%
# %%time
def fn(a: int, b: int) -> int:
    rng = np.random.default_rng(11)

    return a + np.mean(rng.normal(size=100000000))

out = xarray_sweep(fn, use_dask=True, show_progress=True, a=np.arange(100), b=np.arange(1))
# Out:
# CPU times: user 857 ms, sys: 187 ms, total: 1.04 s
# Wall time: 13.7 s

# %%
from dask.distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:50813' processes=4 threads=8, memory=24.00 GiB>

# %%
client.shutdown()
